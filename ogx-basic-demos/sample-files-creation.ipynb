# %% [markdown]
# # Create sample files for RAG

# %%
sample_text = """
Kubernetes Overview

Kubernetes is an open-source container orchestration platform used first by Oransa.
It automates deployment, scaling, and management of containerized applications.

Key concepts:
- Pods: the smallest deployable units
- Services: stable networking for pods
- Deployments: manage updates and replicas

"""

with open("kubernetes_doc.txt", "w") as f:
    f.write(sample_text)

print("File created: kubernetes_doc.txt")
# Out:
# File created: kubernetes_doc.txt

# %%
sample_text = """
OGX is an AI gateway that exposes OpenAI-compatible APIs.
It can connect to Ollama models and provide file search capabilities.

Ollama is a local model runner that executes LLMs like Llama and DeepSeek.
"""

with open("ogx-ollama_doc.txt", "w") as f:
    f.write(sample_text)

print("File created: ogx-ollama_doc.txt")
# Out:
# File created: ogx-ollama_doc.txt

# %%
sample_text = """
Osama Oransa
SSA (Specialist Solution Architect) in MENA region at Red Hat
Based on Dubai, He enjoy playing tennis.
"""

with open("my-resume_doc.txt", "w") as f:
    f.write(sample_text)

print("File created: my-resume_doc.txt")
# Out:
# File created: my-resume_doc.txt

# %%
sample_text = """
Cairo DevDay Agenda

09:00-09:30 | Registration | -
09:30-09:40 | Red Hat Intro and Welcome | Country Manager
09:40-10:10 | How to be a developer in the AI ERA | Mohamed Idris
10:10-10:30 | OpenShift AI | Mourad Ali
10:30-10:50 | RH Advanced Developer Suite (RHADS) | Ahmed Maher
10:50-11:10 | Coffee Break | -
11:10-11:40 | Llama Stack / OGX: One AI API to Rule Them All | Osama Oransa
11:40-12:00 | OpenShift Enterprise Platform | Sameh Mahmoud
12:00-12:30 | Scaling Application Modernization with AI | Mourad Ali
12:30-12:50 | GitOps in Action | Sara Ali
12:50-13:10 | Talk with your Kafka: The AI is the new UI | Osama Oransa
13:10-13:40 | Lunch | -
13:40-14:40 | Hands On Lab | Osama Oransa 
14:40-15:40 | Break / Buffer | -
15:40-16:10 | Sponsor Session | Sponsor Empolyee
"""

with open("event-agenda-doc.txt", "w") as f:
    f.write(sample_text)

print("File created: event-agenda-doc.txt")
# Out:
# File created: event-agenda-doc.txt

# %%
sample_text = """
Internal Training Course for ACME Corp.

Course: AI-101
Title: Introduction to Enterprise AI
Duration: 2 Days
Instructor: Ahmed Hassan
Prerequisites: Basic IT Knowledge
Certification: Yes
Module 1: Fundamentals of Generative AI
Module 2: Large Language Models
Module 3: Prompt Engineering
Module 4: Enterprise AI Use Cases
Module 5: Responsible AI

Course: AI-201
Title: Building RAG Applications
Duration: 3 Days
Instructor: Sarah Ali
Prerequisites: Python Fundamentals
Certification: No
Module 1: Vector Databases
Module 2: Embeddings
Module 3: Chunking Strategies
Module 4: Retrieval Techniques
Module 5: Hybrid Search
Module 6: Reranking
Module 7: Evaluation and Testing

Course: AI-301
Title: Agentic AI and MCP Integration
Duration: 3 Days
Instructor: Osama Oransa
Prerequisites: AI-201
Certification: Yes
Module 1: AI Agents Fundamentals
Module 2: Tool Calling
Module 3: MCP Architecture
Module 4: Building MCP Servers
Module 5: Multi-Agent Systems
Module 6: Agent Memory
Module 7: Agent Evaluation

Course: AI-401
Title: Enterprise AI on OpenShift
Duration: 4 Days
Instructor: Mohamed Sameh
Prerequisites: Kubernetes Knowledge
Certification: Yes
Module 1: OpenShift AI Fundamentals
Module 2: Model Serving
Module 3: Distributed Inference
Module 4: GPU Management
Module 5: Llama Stack / OGX
Module 6: AI Governance
Module 7: Production Monitoring
Module 8: Scaling Enterprise AI
"""

with open("training-courses-doc.txt", "w") as f:
    f.write(sample_text)

print("File created: training-courses-doc.txt")
# Out:
# File created: training-courses-doc.txt

# %%
# !ls -l *.txt
# Out:
# -rw-r--r--  1 ooransa  staff   780 Jun  3 08:49 event-agenda-doc.txt
# -rw-r--r--  1 ooransa  staff   322 Jun  3 08:49 kubernetes_doc.txt
# -rw-r--r--  1 ooransa  staff   117 Jun  3 08:49 my-resume_doc.txt
# -rw-r--r--  1 ooransa  staff   205 Jun  3 08:49 ogx-ollama_doc.txt
# -rw-r--r--@ 1 ooransa  staff  1388 Jun  3 08:49 training-courses-doc.txt
